# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from scipy import ndimage
from skimage import exposure
from skimage import feature
import numpy as np


image = mpimg.imread(r"C:\Users\user\Downloads\Image 1.jpg")

plt.imshow(image)
plt.axis('off')
plt.show()

# %%
gamma = 2
adjusted_image = exposure.adjust_gamma(image, gamma)

plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 2)
plt.imshow(adjusted_image)
plt.title(f'Контрастність збільшена')
plt.axis('off')

plt.tight_layout()
plt.show()

# %%
red_channel = image[:, :, 0]
green_channel = image[:, :, 1]
blue_channel = image[:, :, 2]

plt.figure(figsize=(15, 5))

plt.subplot(1, 3, 1)
plt.imshow(red_channel, cmap='Reds')
plt.title('Червоний канал')
plt.axis('off')

plt.subplot(1, 3, 2)
plt.imshow(green_channel, cmap='Greens')
plt.title('Зелений канал')
plt.axis('off')

plt.subplot(1, 3, 3)
plt.imshow(blue_channel, cmap='Blues')
plt.title('Синій канал')
plt.axis('off')

plt.tight_layout()
plt.show()

# %%
gray_image = np.mean(image, axis=2)
plt.imshow(gray_image, cmap='gray')
plt.title('Black and white image')
plt.axis('off')
plt.show()

# %%
blurred_image = ndimage.gaussian_filter(image, sigma=10)
plt.imshow(blurred_image)
plt.title('Blurred image')
plt.axis('off')
plt.show()

# %%
edges = feature.canny(image[:,:,0], sigma=1) 
plt.imshow(edges, cmap='gray')
plt.title('Contour detection')
plt.axis('off')
plt.show()

# %%
gradient = ndimage.morphological_gradient(grayscale_image, size=(3, 3))

plt.imshow(gradient, cmap='gray')
plt.title('Контур білого на чорному')
plt.axis('off')
plt.show()
